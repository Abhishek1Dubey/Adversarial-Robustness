# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek1Dubey/Adversarial-Robustness/blob/main/Copy_of_Adversarial_Robustness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Adversarial Robustness v0.1

# %% [markdown]
# ## Introduction & Setup

# %% [markdown]
# Adversarial examples are examples designed in order to cause an machine
#
# ---
#
# learning system to malfunction. Here, an adversary is taking a real image of a panda and adds some adversarially generated noise to get the adversarial example. The adversarial noise is designed to have small distance from the original image, so it still looks like a panda for humans. However, the model now believes its a gibbon with 99.3\% confidence.
#
# ![picture](https://drive.google.com/uc?export=view&id=1kvJRRUDssx8ZarAH71-nxv2c2_RBNz4G)

# %%
# Cloning the files from github

# !git clone --branch adversarial https://github.com/oliverzhang42/safety.git
# !pip3 install robustness=='1.2.1.post2'
# !pip3 install torchvision=='0.10.0'
# Out:
# Cloning into 'safety'...
# remote: Enumerating objects: 260, done.
# remote: Total 260 (delta 0), reused 0 (delta 0), pack-reused 260
# Receiving objects: 100% (260/260), 177.09 MiB | 16.26 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# Updating files: 100% (11/11), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting robustness==1.2.1.post2
#   Downloading robustness-1.2.1.post2-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 KB 2.8 MB/s eta 0:00:00
# Collecting gitpython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (1.13.1+cu116)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (1.3.5)
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cox
#   Downloading cox-0.1.post3-py3-none-any.whl (18 kB)
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (0.14.1+cu116)
# Requirement already satisfied: tables in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (3.7.0)
# Collecting py3nvml
#   Downloading py3nvml-0.2.7-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 KB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: grpcio in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (1.51.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (0.11.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (1.2.1)
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (1.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (4.65.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (5.4.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from robustness==1.2.1.post2) (3.5.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->robustness==1.2.1.post2) (4.39.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->robustness==1.2.1.post2) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->robustness==1.2.1.post2) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->robustness==1.2.1.post2) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->robustness==1.2.1.post2) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->robustness==1.2.1.post2) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->robustness==1.2.1.post2) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas->robustness==1.2.1.post2) (2022.7.1)
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->robustness==1.2.1.post2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->robustness==1.2.1.post2) (3.1.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.9/dist-packages (from tables->robustness==1.2.1.post2) (2.8.4)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from tensorboardX->robustness==1.2.1.post2) (3.19.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->robustness==1.2.1.post2) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision->robustness==1.2.1.post2) (2.25.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->robustness==1.2.1.post2) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->robustness==1.2.1.post2) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->robustness==1.2.1.post2) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->robustness==1.2.1.post2) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->robustness==1.2.1.post2) (2.10)
# Building wheels for collected packages: GPUtil
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7409 sha256=8117ed7160529c7cdc76ea747a727cc8fc839957dfde64d7bb3c69ed27cf6fb9
#   Stored in directory: /root/.cache/pip/wheels/2b/b5/24/fbb56595c286984f7315ee31821d6121e1b9828436021a88b3
# Successfully built GPUtil
# Installing collected packages: GPUtil, xmltodict, tensorboardX, smmap, dill, py3nvml, gitdb, gitpython, cox, robustness
# Successfully installed GPUtil-1.4.0 cox-0.1.post3 dill-0.3.6 gitdb-4.0.10 gitpython-3.1.31 py3nvml-0.2.7 robustness-1.2.1.post2 smmap-5.0.0 tensorboardX-2.6 xmltodict-0.13.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchvision==0.10.0
#   Downloading torchvision-0.10.0-cp39-cp39-manylinux1_x86_64.whl (22.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.1/22.1 MB 51.6 MB/s eta 0:00:00
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp39-cp39-manylinux1_x86_64.whl (831.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.4/831.4 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision==0.10.0) (1.22.4)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision==0.10.0) (8.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.9.0->torchvision==0.10.0) (4.5.0)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.13.1+cu116 requires torch==1.13.1, but you have torch 1.9.0 which is incompatible.
# Successfully installed torch-1.9.0 torchvision-0.10.0

# %%
# Importing all the necessary libraries

import torch
import torch.nn.functional as F
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from safety.utils import utils
from safety.lesson1 import adversarial
from torch import nn
from torchvision import models

# %matplotlib inline

# %% [markdown]
# ## First Adversarial Attack using FGSM

# %% [markdown]
# ### Untargeted FGSM

# %% [markdown]
# The first method we look at is the untargeted Fast Gradient Sign Method (FGSM) proposed by [Goodfellow et al.](https://arxiv.org/pdf/1412.6572.pdf). The attack constructs adversarial examples as follows:
#
# $$x_\text{adv} = x + \epsilon\cdot\text{sign}(\nabla_xJ(\theta, x, y))$$
#
# where
#
# *   $x_\text{adv}$ : Adversarial image.
# *   $x$ : Original input image.
# *   $y$ : Original input label.
# *   $\epsilon$ : Multiplier to ensure the perturbations are small.
# *   $\theta$ : Model parameters.
# *   $J$ : Loss.
#
# The current attack formulation is considered 'untargeted' because it only seeks to maximize loss rather than to trick the model into predicting a specific label.

# %% [markdown]
# Try implementing the untargeted FGSM method for a batch of images yourself!

# %%
def untargeted_FGSM(x_batch, true_labels, network, normalize, eps, **kwargs):
    """
    Perform the untargeted FGSM attack on a batch of images.
    Args:
        x_batch (torch.Tensor): Batch of images.
        true_labels (torch.Tensor): True labels for the batch of images.
        network (nn.Module): Model used for the attack.
        normalize (bool): Whether to normalize the input images.
        eps (float): Perturbation size for the attack.
        **kwargs: Additional parameters.
    Returns:
        torch.Tensor: Perturbed batch of images.
    """
    x_batch.requires_grad = True
    
    # Forward pass
    outputs = network(x_batch)
    _, predicted_labels = torch.max(outputs.data, 1)
    
    # Calculate loss
    loss = F.nll_loss(outputs, true_labels)
    
    # Backward pass
    network.zero_grad()
    loss.backward()
    data_grad = x_batch.grad.detach()
    
    # FGSM attack
    perturbed_x_batch = x_batch + eps * torch.sign(data_grad)
    perturbed_x_batch = torch.clamp(perturbed_x_batch, 0, 1)
    
    return perturbed_x_batch

# %%
# Test the method
adversarial.test_untargeted_attack(untargeted_FGSM, eps=50/255.)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %% [markdown]
# If things go well, the model should switch from predicting 'giant panda' to predicting 'brown bear' or some other class. Additionally, try increasing the epsilon to see the noise more clearly.

# %% [markdown]
# ### Targeted FGSM

# %% [markdown]
# In addition to the untargeted FGSM which simply seeks to maximize loss, we can also create targeted adversarial attacks. We do this using the following equation:
#
# $$x_{adv} = x - \epsilon\cdot\text{sign}(\nabla_xJ(\theta, x, y_{target}))$$
#
# where
#
# *   $x_{adv}$ : Adversarial image.
# *   $x$ : Original input image.
# *   $y_{target}$ : The target label.
# *   $\epsilon$ : Multiplier to ensure the perturbations are small.
# *   $\theta$ : Model parameters.
# *   $J$ : Loss.

# %% [markdown]
# Try implementing the targeted FGSM method for a batch of images yourself!

# %%
def targeted_FGSM(x_batch, target_labels, network, normalize, eps=8/255., **kwargs):
    """Generates a batch of targeted FGSM adversarial examples

    Args:
      x_batch (torch.Tensor): the unnormalized input example.
      target_labels (torch.Tensor): the labels the model will predict after the attack.
      network (nn.Module): the network to attack.
      normalize (function): a function which normalizes a batch of images 
          according to standard imagenet normalization.
      eps (float): the bound on the perturbations.
    """
    loss_fn = nn.CrossEntropyLoss(reduce="mean")
    x_batch.requires_grad = True

    # Forward pass
    outputs = network(normalize(x_batch))
    _, original_labels = torch.max(outputs, dim=1)

    # Calculate loss
    loss = loss_fn(outputs, target_labels)

    # Backward pass
    network.zero_grad()
    loss.backward()
    data_grad = x_batch.grad.data

    # FGSM attack
    perturbed_x_batch = x_batch - eps * torch.sign(data_grad)
    perturbed_x_batch = torch.clamp(perturbed_x_batch, 0, 1)

    # Check if attack was successful
    outputs = network(normalize(perturbed_x_batch))
    _, perturbed_labels = torch.max(outputs, dim=1)

    if torch.equal(perturbed_labels, target_labels):
        x_adv = perturbed_x_batch
    else:
        x_adv = x_batch

    return x_adv

# %% [markdown]
# **Note that even if the implementation is perfect, FGSM is not able to generate effective targeted attacks, so don't expect the output image to assign a high probability to the target label.**

# %%
adversarial.test_targeted_attack(targeted_FGSM, target_idx=8, eps=8/255.)
# Out:
# The target index corresponds to a label of hen!
# /usr/local/lib/python3.9/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# ## Additional Adversarial Attacks

# %% [markdown]
# ## Implementing L2 normalization and clamping

# %% [markdown]
# We will implement some helper functions that we can use for the Projected Gradient Descent (PGD) L2 method below.
#
# For the normalize_l2 function we will be returning the following value
#
# $$\frac{x}{||x||_{2}}$$
#
# For the tensor_clamp_l2 function we will compute and return the following value
#
# \begin{equation}
#     X=
#     \begin{cases}
#       clamp(x), & \text{if}\ ||x-c||_2 > r \\
#       x, & \text{otherwise}
#     \end{cases}
#   \end{equation}
#
# where
# $ \text{clamp}(x) = c + \frac{x-c}{||x-c||_2} ⋅ r$, X is the return value, x is the input, c (center) is a tensor of the same shape as x, and r (radius) is a scalar value.

# %% [markdown]
# Try implementing the batched version of normalize_l2 and tensor_clamp_l2 below!

# %%
def normalize_l2(x_batch):
    """
    Expects x_batch.shape == [N, C, H, W]
    where N is the batch size, 
    C is the channels (or colors in our case),
    H, W are height and width respectively.

    Note: To take the l2 norm of an image, you will want to flatten its dimensions (be careful to preserve the batch dimension of x_batch).
    """
    # Compute the l2 norm along the channel dimension (axis=1)
    norm = torch.norm(x_batch.view(x_batch.shape[0], -1), p=2, dim=1, keepdim=True)
    # Return the normalized tensor
    return x_batch / norm.view(norm.shape[0], 1, 1, 1)

# %%
def tensor_clamp_l2(x, c, r):
    """
    Given a tensor x, center c, and radius r, compute the L2 distance between x and c.
    If the L2 distance is greater than r, project x onto the L2 ball centered at c with radius r.
    """
    # Compute the L2 distance between x and c
    dist = torch.norm(x - c, p=2, dim=1, keepdim=True)
    # If the distance is greater than r, clamp the tensor to the ball
    if torch.any(dist > r):
        # Compute the clamped tensor according to the formula in the prompt
        clamped = c + (x - c) * r / dist
        # If the distance is still greater than r, re-clamp the tensor to the ball
        clamped_dist = torch.norm(clamped - c, p=2, dim=1, keepdim=True)
        clamped = c + (clamped - c) * r / clamped_dist
        return clamped
    else:
        return x

# %%
def PGD_l2(x_batch, true_labels, network, normalize, num_steps=20, step_size=3./255, eps=128/255., **kwargs):
        """
        :return: perturbed batch of images
        """
        # Initialize our adversial image
        x_adv = x_batch.detach().clone()
        x_adv += torch.zeros_like(x_adv).uniform_(-eps, eps)

        for _ in range(num_steps):
            x_adv.requires_grad_()
            
            # Calculate gradients
            with torch.enable_grad():
              logits = network(normalize(x_adv))
              loss = F.cross_entropy(logits, true_labels, reduction='sum')

            # Normalize the gradients with your L2
            grad = normalize_l2(torch.autograd.grad(loss, x_adv, only_inputs=True)[0])

            # Take a step in the gradient direction.
            x_adv = x_adv.detach() + step_size * grad
            # Project (by clamping) the adversarial image back onto the hypersphere
            # around the image.
            x_adv = tensor_clamp_l2(x_adv, x_batch, eps).clamp(0, 1)

        return x_adv

# %% [markdown]
# Try out the helper functions you wrote. Note how the hyperparameters differ depending on the attack that one is using. You can see more examples below.

# %%
adversarial.test_untargeted_attack(PGD_l2, eps=128/255.)

# %% [markdown]
# In addition to your implementations of FGSM, we will provide you with an
#
# ---
#
# implementation of Projected Gradient Descent (PGD) by [Madry et al.](https://arxiv.org/pdf/1706.06083.pdf). As mentioned in the lecture, PGD can be seen a stronger version of FGSM which applies FGSM many times. We provide both targeted and untargeted versions.

# %%
def untargeted_PGD(x_batch, true_labels, network, normalize, num_steps=10, step_size=0.01, eps=8/255., **kwargs):
  """Generates a batch of untargeted PGD adversarial examples

  Args:
    x_batch (torch.Tensor): the batch of unnormalized input examples.
    true_labels (torch.Tensor): the batch of true labels of the example.
    network (nn.Module): the network to attack.
    normalize (function): a function which normalizes a batch of images 
        according to standard imagenet normalization.
    num_steps (int): the number of steps to run PGD.
    step_size (float): the size of each PGD step.
    eps (float): the bound on the perturbations.
  """
  x_adv = x_batch.detach().clone()
  x_adv += torch.zeros_like(x_adv).uniform_(-eps, eps)

  for i in range(num_steps):
    x_adv.requires_grad_()
    
    # Calculate gradients
    with torch.enable_grad():
      logits = network(normalize(x_adv))
      loss = F.cross_entropy(logits, true_labels, reduction='sum')
    grad = torch.autograd.grad(loss, x_adv, only_inputs=True)[0]
    
    # Perform one gradient step
    x_adv = x_adv.detach() + step_size * torch.sign(grad.detach())
    
    # Project the image to the ball.
    x_adv = torch.maximum(x_adv, x_batch - eps)
    x_adv = torch.minimum(x_adv, x_batch + eps)

  return x_adv

# %%
adversarial.test_untargeted_attack(untargeted_PGD, eps=8/255.)

# %%
def targeted_PGD(x_batch, target_labels, network, normalize, num_steps=100, step_size=0.01, eps=8/255., **kwargs):
  """Generates a batch of untargeted PGD adversarial examples

  Args:
    x_batch (torch.Tensor): the batch of preprocessed input examples.
    target_labels (torch.Tensor): the labels the model will predict after the attack.
    network (nn.Module): the network to attack.
    normalize (function): a function which normalizes a batch of images 
        according to standard imagenet normalization.
    num_steps (int): the number of steps to run PGD.
    step_size (float): the size of each PGD step.
    eps (float): the bound on the perturbations.
  """
  x_adv = x_batch.detach().clone()
  x_adv += torch.zeros_like(x_adv).uniform_(-eps, eps)

  for i in range(num_steps):
    x_adv.requires_grad_()
    
    # Calculate gradients
    with torch.enable_grad():
      logits = network(normalize(x_adv))
      loss = F.cross_entropy(logits, target_labels, reduction='sum')
    grad = torch.autograd.grad(loss, x_adv, only_inputs=True)[0]
    
    # Perform one gradient step
    # Note that this time we use gradient descent instead of gradient ascent
    x_adv = x_adv.detach() - step_size * torch.sign(grad.detach())
    
    # Project the image to the ball
    x_adv = torch.maximum(x_adv, x_batch - eps)
    x_adv = torch.minimum(x_adv, x_batch + eps)
  
  return x_adv

# %%
# Try changing the target_idx around!
adversarial.test_targeted_attack(targeted_PGD, target_idx=1, eps=8/255.)
# Out:
# The target index corresponds to a label of goldfish!

# %% [markdown]
# ## Attacks on Adversarially Trained Models
# We devote this section to attacking an adversarially trained model. As a reminder, a model which has been "adversarially trained" means that it has been exposed to a load of adversarial examples over training and has specifically trained to recognize them properly.
#
# In this section, we hope to demonstrate that adversarial attacks look a lot different if you're attacking an adversarially trained model.
#
# The model we use was taken from this repository and is an L∞ robust ResNet18 trained with adversarial examples of ϵ=8/255.

# %% [markdown]
# ### Attacking Normally Trained Models

# %%
# Attack a normal model (we only support targeted methods)
adversarial.attack_normal_model(
    targeted_PGD, 
    target_idx=10, 
    eps=8/255., 
    num_steps=10, 
    step_size=0.01
)
# Out:
# The target index corresponds to a label of brambling!

# %% [markdown]
# ### Attacking Adversarially Trained Models

# %%
# Attack an adversarially trained model (we only support targeted methods)
adversarial.attack_adversarially_trained_model(
    targeted_PGD, 
    target_idx=10, 
    eps=8/255., 
    num_steps=10, 
    step_size=0.01
)
# Out:
# => loading checkpoint 'safety/lesson1/checkpoints/resnet18_linf_eps8.0.ckpt'
# => loaded checkpoint 'safety/lesson1/checkpoints/resnet18_linf_eps8.0.ckpt' (epoch 90)
#
# The target index corresponds to a label of brambling!

# %% [markdown]
# ### Comparing Adversarial Attacks against different models

# %% [markdown]
# Take a few minutes to play around with the previous code. Jot down three observations about how attacking an adversarially trained model differs from attacking a normal model.
#
# Example responses:
#
# 1. The confidence of typical models is higher than adversarially trained models
# 2. [Fill in Observation]
# 3. [Fill in Observation]

# %% [markdown]
# ## Accuracy vs Number of PGD Steps
#
# In this section, we seek to see how accuracy varies as we change the number of steps in PGD. Your first task is to write a function which calculates the model's accuracy on adversarially generated images. For this case, we use untargeted PGD.

# %%
def adversarial_accuracy(x_batch, true_labels, network, normalize, num_steps=10, step_size=0.01, eps=8/255.):
    """Generates a batch of adversarial examples using `untargeted_PGD`. Then
    calculates and returns accuracy on said batch of examples.

    Args:
      x_batch (torch.Tensor): the batch of preprocessed input examples.
      true_labels (torch.Tensor): the batch of true labels of the example.
      network (nn.Module): the network to attack.
      normalize (function): a function which normalizes a batch of images 
          according to standard imagenet normalization.
      num_steps (int): the number of steps to run PGD.
      step_size (float): the size of each PGD step.
      eps (float): the bound on the perturbations.

    Note: Consider the networks prediction to be the class with the highest output (aka logit).
    """
    x_adv = untargeted_PGD(x_batch, true_labels, network, normalize, num_steps=num_steps, step_size=step_size, eps=eps)

    with torch.no_grad():
        # Get the logits of the model on the adversarial examples
        logits = network(x_adv)

        # Get the predicted class for each example
        preds = torch.argmax(logits, dim=1)

        # Calculate the accuracy
        accuracy = (preds == true_labels).float().mean()

    return accuracy

# %% [markdown]
# Then, use the previous function to plot the accuracy against the number of PGD steps.

# %%
x_batch = torch.load('safety/lesson1/imagenet_batch').cuda()
true_labels = torch.load('safety/lesson1/imagenet_labels').cuda()
network = adversarial.get_adv_trained_model().eval()
normalization_function = utils.IMAGENET_NORMALIZE

#########################
# Enter Your Code Here! #
#########################
import matplotlib.pyplot as plt

x_batch = torch.load('safety/lesson1/imagenet_batch').cuda()
true_labels = torch.load('safety/lesson1/imagenet_labels').cuda()
network = adversarial.get_adv_trained_model().eval()
normalization_function = utils.IMAGENET_NORMALIZE

accuracies = []
num_steps_list = [1, 2, 4, 8, 16, 32, 64, 164]

for num_steps in num_steps_list:
    accuracy = adversarial_accuracy(x_batch, true_labels, network, normalization_function, num_steps=num_steps)
    accuracies.append(accuracy.item())

plt.plot(num_steps_list, accuracies, marker='o')
plt.xlabel('Number of PGD Steps')
plt.ylabel('Accuracy')
plt.title('PGD Accuracy vs Number of Steps')
plt.show()


# call adversarial_accuracy(...) for several num_steps and plot
# Out:
# => loading checkpoint 'safety/lesson1/checkpoints/resnet18_linf_eps8.0.ckpt'
# => loaded checkpoint 'safety/lesson1/checkpoints/resnet18_linf_eps8.0.ckpt' (epoch 90)
# => loading checkpoint 'safety/lesson1/checkpoints/resnet18_linf_eps8.0.ckpt'
# => loaded checkpoint 'safety/lesson1/checkpoints/resnet18_linf_eps8.0.ckpt' (epoch 90)
